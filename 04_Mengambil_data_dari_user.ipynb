# %%
# Episode input user

# data yang dimasukan pasti string
data = input("Masukan data: ")

print("data = ",data,",type =",type(data))
# Out:
# data =  10 ,type = <class 'str'>

# %%
# jika kita ingin mengambil int dam float, maka
angka1 = float(input("masukan angka: "))
angka2 = int(input("masukan angka: "))

print("data = ",angka1,",type =",type(angka1))
print("data = ",angka2,",type =",type(angka2))
# Out:
# data =  12.2 ,type = <class 'float'>
# data =  12 ,type = <class 'int'>

# %%
# bagaimana dengan boolean
biner = bool(int(input("masukan nilai boolean: ")))

print("data = ",biner,",type =",type(biner))
# Out:
# data =  True ,type = <class 'bool'>
